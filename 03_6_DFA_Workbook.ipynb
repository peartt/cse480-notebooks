# %% [markdown]
# # First let's import, then work through the "small" cases of DFA.

# %%
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import sys

# -- Detect if in Own Install or in Colab
try:
    import google.colab
    OWN_INSTALL = False
except:
    OWN_INSTALL = True
    
if OWN_INSTALL:

  sys.path[0:0] = ['../../../../..',  '../../../../../3rdparty',  
                   '../../../..',  '../../../../3rdparty',  
                   '../../..',     '../../../3rdparty', 
                   '../..',        '../../3rdparty',
                   '..',           '../3rdparty', '../Jove', '../Jove/jove' ]

else: # In colab
  ! if [ ! -d Jove ]; then git clone https://github.com/ganeshutah/Jove Jove; fi
  sys.path.append('./Jove')
  sys.path.append('./Jove/jove')

# -- common imports --
from jove.LangDef   import *  #-- mainly for nthnumeric
from jove.Def_md2mc import *  #-- for md2mc
from jove.Def_DFA   import *  #-- for all DFA functions
from jove.DotBashers import * #-- for dotObj_dfa

from IPython import display 
from base64 import b64decode
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# # Questions to Answer for Each
#
# * IS this a DFA?
# * Which strings are accepted by it?
# * Which strings are rejected by it?
# * What language is recognized by it?

# %%
# 1
dotObj_dfa(md2mc('''

  DFA 

  IF : 0|1 -> IF

'''))

# %%
answer_1_base64_encoded = '...'
display.Image(b64decode(answer_1_base64_encoded))

# %%
# 2
dotObj_dfa(md2mc('''

  DFA 

   I : 0|1 -> I

'''))

# %%
answer_2_base64_encoded = '...'
display.Image(b64decode(answer_2_base64_encoded))

# %% [markdown]
# Is this next one even a DFA over {0, 1}? Why or why not?

# %%
# 3
dotObj_dfa(md2mc('''

  DFA 

  I : 0 -> I

'''))

# %%
answer_3_base64_encoded = '...'
display.Image(b64decode(answer_3_base64_encoded))

# %% [markdown]
# Is that DFA (#3) a DFA over {0}?

# %%
answer_4_base64_encoded = '...'
display.Image(b64decode(answer_4_base64_encoded))

# %%
# 5
dotObj_dfa(md2mc('''

  DFA 

  IF : 0|1 -> A
  
   A : 0|1 -> A

'''))

# %% [markdown]
# Wait a minute, let's apply the FuseEdges=True argument (see next cell).

# %%
# 5
dotObj_dfa(md2mc('''

  DFA 

  IF : 0|1 -> A
   A : 0|1 -> A

'''), FuseEdges=True)

# %%
answer_5_base64_encoded = '...'
display.Image(b64decode(answer_5_base64_encoded))

# %% [markdown]
# For this next one, write your answer as a language concatenation!

# %%
# 6
dotObj_dfa(md2mc('''

  DFA 

   I : 0|1 -> F
   
   F : 0|1 -> F

'''), FuseEdges=True)

# %%
answer_6_base64_encoded = '...'
display.Image(b64decode(answer_6_base64_encoded))

# %%
all_answers_base64_encoded = '...'

display.Image(b64decode(all_answers_base64_encoded))
