# %% [markdown]
# <a href="https://colab.research.google.com/github/peartt/cse480-notebooks/blob/master/14_1_My_Final_Grade_Claim_for_W21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Evidence 1 Week 10. [Sub-seciton of Exercise 15.2.3.4](https://colab.research.google.com/github/peartt/cse480-notebooks/blob/master/10_2_Ponder_and_Prove_the_Post_Correspondence_Problem.ipynb#scrollTo=cBYh2gmuZxUZ) Even though PCP's can easily spiral out of polynomial time, singleton alphabet PCP are easily decidable which I think is really cool, as I give a simple example of an 'impossible' singleton PCP.

# %% [markdown]
# Evidence 2 Week 11 [Exercise 16.7.2.12](https://colab.research.google.com/github/peartt/cse480-notebooks/blob/master/11_2_Ponder_and_Prove_NP_Completeness.ipynb#scrollTo=0FEjXwMpiZF-) Bringing together how a $\Phi$ that is composed of AND-ed $\phi$'s cannot have be satisfiable if it has two or more $\phi$ that both A)use all variables in $\Phi$ and B) are true or all false. I think it is a really cool thing, even if it is a simple thing.

# %% [markdown]
# Evidence 3 Week 12 [Connection to Turing Machines](https://colab.research.google.com/github/peartt/cse480-notebooks/blob/master/12_3_More_About_Boolean_Logic_and_BDDs.ipynb#scrollTo=P4wfQNyobYPO) This TODO makes me think how if I had a Turing Machine that for all input $w$ resulted in a tautology (either $e$ or $\lnot e$, it doesn't particularly matter), then I could express that Turing Machine by a different Turing Machine that results in the same $e$ for all input $w$.
